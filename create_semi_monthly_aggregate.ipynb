# %%
import pandas as pd

# %%
# Read in data
df = pd.read_csv('Best_30_Year_Dataset_With_Depth.csv', index_col=0)
# Use datetime as index
df.index = pd.to_datetime(df.index)

# %%
# Aggregate by month
monthly_df = df.groupby(pd.Grouper(freq='SM')).mean()
monthly_df.index = monthly_df.index.strftime('up to %Y-%m-%d')
# Drop cols that are all NaNs
monthly_df = monthly_df.dropna('columns', how='all')

# %%
# Which rows have very little data?
monthly_df.index[monthly_df.isna().sum(axis=1) > len(monthly_df.columns)-5]
# Out:
# Index([], dtype='object')

# %%
# Looks like we should start in 1893
monthly_df = monthly_df[1086:-2]
monthly_df
# Out:
#               PRCP      SNOW   SNWD  PRCP_US1UTBE0002  SNOW_US1UTBE0002  \
# 1893-01        NaN       NaN    NaN               NaN               NaN
# 1893-02        NaN       NaN    NaN               NaN               NaN
# 1893-03        NaN       NaN    NaN               NaN               NaN
# 1893-04        NaN       NaN    NaN               NaN               NaN
# 1893-05        NaN       NaN    NaN               NaN               NaN
# ...            ...       ...    ...               ...               ...
# 2020-11  12.200000  3.080000  51.00          0.000000              0.00
# 2020-12   7.612903  6.161290  45.70          7.785714              8.25
# 2021-01  12.483871  5.928571  42.75          0.000000              0.00
# 2021-02   0.000000  0.000000    NaN          0.000000              0.00
# 2021-03        NaN       NaN    NaN          0.000000              0.00
#
#          SNWD_US1UTBE0002  PRCP_US1UTBE0003  SNOW_US1UTBE0003  \
# 1893-01               NaN               NaN               NaN
# 1893-02               NaN               NaN               NaN
# 1893-03               NaN               NaN               NaN
# 1893-04               NaN               NaN               NaN
# 1893-05               NaN               NaN               NaN
# ...                   ...               ...               ...
# 2020-11               NaN               NaN               NaN
# 2020-12             120.5               NaN               NaN
# 2021-01               NaN               NaN               NaN
# 2021-02               NaN               NaN               NaN
# 2021-03               NaN               NaN               NaN
#
#          SNWD_US1UTBE0003  PRCP_US1UTBE0004  ...  TMIN_USW00024193  \
# 1893-01               NaN               NaN  ...               NaN
# 1893-02               NaN               NaN  ...               NaN
# 1893-03               NaN               NaN  ...               NaN
# 1893-04               NaN               NaN  ...               NaN
# 1893-05               NaN               NaN  ...               NaN
# ...                   ...               ...  ...               ...
# 2020-11               NaN               NaN  ...               NaN
# 2020-12               NaN               NaN  ...               NaN
# 2021-01               NaN               NaN  ...               NaN
# 2021-02               NaN               NaN  ...               NaN
# 2021-03               NaN               NaN  ...               NaN
#
#          TMAX_USW00024193  PRCP_USW00053167  TMIN_USW00053167  \
# 1893-01               NaN               NaN               NaN
# 1893-02               NaN               NaN               NaN
# 1893-03               NaN               NaN               NaN
# 1893-04               NaN               NaN               NaN
# 1893-05               NaN               NaN               NaN
# ...                   ...               ...               ...
# 2020-11               NaN               NaN               NaN
# 2020-12               NaN               NaN               NaN
# 2021-01               NaN               NaN               NaN
# 2021-02               NaN               NaN               NaN
# 2021-03               NaN               NaN               NaN
#
#          TMAX_USW00053167  PRCP_USW00094097  SNWD_USW00094097  \
# 1893-01               NaN               NaN               NaN
# 1893-02               NaN               NaN               NaN
# 1893-03               NaN               NaN               NaN
# 1893-04               NaN               NaN               NaN
# 1893-05               NaN               NaN               NaN
# ...                   ...               ...               ...
# 2020-11               NaN          6.966667               NaN
# 2020-12               NaN          3.096774               NaN
# 2021-01               NaN          6.483871               NaN
# 2021-02               NaN         10.214286               NaN
# 2021-03               NaN          0.000000               NaN
#
#          TMIN_USW00094097  TMAX_USW00094097        depth
# 1893-01               NaN               NaN  4201.700000
# 1893-02               NaN               NaN  4201.900000
# 1893-03               NaN               NaN  4202.000000
# 1893-04               NaN               NaN  4202.400000
# 1893-05               NaN               NaN  4202.800000
# ...                   ...               ...          ...
# 2020-11        -50.566667         92.800000  4192.176667
# 2020-12       -124.096774          4.419355  4192.190323
# 2021-01       -102.677419          4.935484  4192.303571
# 2021-02        -55.964286         33.107143          NaN
# 2021-03        -85.000000         63.500000          NaN
#
# [1539 rows x 1505 columns]

# %%
# Do the endpoints have enough data?
monthly_df.iloc[0].dropna()
# Out:
# PRCP_US1UTWS0009       3.500000
# PRCP_USC00421285      15.142857
# PRCP_USC00421918      10.000000
# TMIN_USC00421918     -29.714286
# TMAX_USC00421918     139.571429
# PRCP_USC00422294       8.428571
# TMIN_USC00422294     -18.571429
# TMAX_USC00422294     146.000000
# PRCP_USC00422726       6.571429
# PRCP_USC00423335       8.142857
# TMIN_USC00424846     -11.928571
# TMAX_USC00424846     105.571429
# PRCP_USC00425705      16.181818
# TMIN_USC00425705     -57.000000
# TMAX_USC00425705     126.000000
# PRCP_USC00427255      43.000000
# TMIN_USC00427255      10.714286
# TMAX_USC00427255     128.571429
# PRCP_USC00427576       4.357143
# TMIN_USC00427576      18.090909
# PRCP_USC00428114       0.928571
# TMIN_USC00428114      52.076923
# TMAX_USC00428114     158.923077
# PRCP_USC00428668       5.571429
# PRCP_USC00428741       9.214286
# SNOW_USC00428741       0.000000
# SNWD_USC00428741       0.000000
# TMIN_USC00428741      39.000000
# TMAX_USC00428741     150.714286
# TMIN_USC00428939       4.428571
# TMAX_USC00428939     145.571429
# PRCP_USC00429133       9.214286
# TMIN_USC00429133       0.428571
# TMAX_USC00429133     130.571429
# PRCP_USC00429560      17.714286
# TMIN_USC00429560     -22.928571
# TMAX_USC00429560     108.357143
# PRCP_USW00024126       9.285714
# SNOW_USW00024126       0.714286
# SNWD_USW00024126       0.000000
# TMIN_USW00024126      27.071429
# TMAX_USW00024126     161.500000
# depth               4195.250000
# Name: up to 1958-10-31, dtype: float64

# %%
monthly_df.iloc[-1].dropna()
# Out:
# PRCP_US1UTWS0009      0.0
# PRCP_USC00421285      0.0
# PRCP_USC00421918      0.0
# PRCP_USC00422294      0.0
# TMIN_USC00422294    -44.0
# TMAX_USC00422294    206.0
# PRCP_USC00422726      0.0
# PRCP_USC00423335      0.0
# TMIN_USC00424846    -33.0
# TMAX_USC00424846    167.0
# PRCP_USC00425705      0.0
# TMIN_USC00425705    -56.0
# TMAX_USC00425705    222.0
# PRCP_USC00427255      0.0
# TMIN_USC00427255    -11.0
# TMAX_USC00427255    206.0
# PRCP_USC00427576      0.0
# TMIN_USC00427576     44.0
# PRCP_USC00428114      0.0
# TMIN_USC00428114     39.0
# TMAX_USC00428114    200.0
# PRCP_USC00428668      0.0
# PRCP_USC00428741      0.0
# SNOW_USC00428741      0.0
# SNWD_USC00428741      0.0
# TMIN_USC00428741     44.0
# TMAX_USC00428741    228.0
# TMIN_USC00428939    -11.0
# TMAX_USC00428939    217.0
# PRCP_USC00429133      0.0
# TMIN_USC00429133    -67.0
# TMAX_USC00429133    206.0
# PRCP_USC00429560      0.0
# TMIN_USC00429560   -106.0
# TMAX_USC00429560    189.0
# PRCP_USW00024126      0.0
# SNOW_USW00024126      0.0
# SNWD_USW00024126      0.0
# TMIN_USW00024126     39.0
# TMAX_USW00024126    228.0
# Name: up to 1988-10-31, dtype: float64

# %%
# Yep looks good! Saving to csv
monthly_df.to_csv('Best_30_Years_semi_monthly.csv')
